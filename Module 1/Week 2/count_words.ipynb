# %%
file_path= './P1_data.txt'

with open(file_path, 'r') as file:
    data = file.read().lower()
    data = data.replace('\n', ' ').split(' ')
    data.sort()

def word_count(data):
    word_dict = {word: data.count(word) for word in data}
    return word_dict

word_count(data)
# Out:
# {'a': 7,
#  'again': 1,
#  'and': 1,
#  'are': 1,
#  'at': 1,
#  'be': 1,
#  'become': 2,
#  'bricks': 1,
#  'busy': 1,
#  'but': 1,
#  'came': 1,
#  'can': 3,
#  'cannot': 1,
#  'change': 1,
#  'comes': 2,
#  'conquers': 1,
#  'courage': 1,
#  'day': 1,
#  'different': 1,
#  'employed': 1,
#  'enough': 1,
#  'everything': 1,
#  'firm': 1,
#  'for': 3,
#  'foundation': 1,
#  'from': 1,
#  'get': 2,
#  'have': 1,
#  'he': 1,
#  'help': 1,
#  'him': 1,
#  'himself': 1,
#  'his': 2,
#  'if': 1,
#  'in': 4,
#  'is': 3,
#  'it': 2,
#  'just': 2,
#  'kind': 1,
#  'lay': 1,
#  'life': 2,
#  'looking': 1,
#  'majority': 1,
#  'makes': 1,
#  'man': 6,
#  'mightiest': 1,
#  'mistakes': 1,
#  'morning': 1,
#  'not': 1,
#  'of': 4,
#  'one': 4,
#  'opportunity': 1,
#  'other': 1,
#  'others': 1,
#  'people': 1,
#  'positive': 1,
#  'problems': 1,
#  'profit': 1,
#  'rather': 1,
#  'ready': 1,
#  'secret': 1,
#  'small': 1,
#  'solve': 1,
#  'success': 3,
#  'successful': 2,
#  'the': 5,
# ...
